# %%
from make_predictions import time_delay_predictions
from classify import make_iat_dataframe
from make_predictions import load_data_and_model
from pprint import pprint

# %%
args = {
    'data': '../datasets/data_directional_200-class_100-samples.pkl',
    'model': './minirocket_iat_ridge/model',
    'use_iat': True,
    'label_file': '../collection_scripts/top-1k-curated',
    'direction': None,
    'delay': 0.1
}

# %%
data, y, model = load_data_and_model(args)
# Out:
# Loading data...
# Loading model...

# %%
data = make_iat_dataframe(data, with_direction=True)

# %%
data['time'].describe()
# Out:
# count    359516.000000
# mean          0.084759
# std           0.316803
# min           0.000000
# 25%           0.011658
# 50%           0.026012
# 75%           0.056417
# max          15.004938
# Name: time, dtype: float64

# %%
models = ['./minirocket_logreg_no_direction/model']
delays = [0.001, 0.002, 0.005, 0.01, 0.02, 0.05, 0.1, 0.2, 0.5, 1]
delays.sort()

# %%
all_results = {}
for model in models:
    all_results[model] = {}
    args['model'] = model
    for delay in delays:
        args['delay'] = delay
        acc, overhead = time_delay_predictions(args)
        all_results[model][delay] = (acc, overhead)
    print(model)
    pprint(all_results[model])
# Out:
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.04507782494441075
# F1-Score: 0.039822150759165405
# Modified accuracy: 0.08166565595310289
# Latency increase from base: 0.58%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.044269254093389936
# F1-Score: 0.03876980140545135
# Modified accuracy: 0.08105922781483728
# Latency increase from base: 1.16%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.04548211036992116
# F1-Score: 0.040711337040209565
# Modified accuracy: 0.0820699413786133
# Latency increase from base: 2.91%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.046694966646452396
# F1-Score: 0.041826503587884895
# Modified accuracy: 0.08348494036789973
# Latency increase from base: 5.81%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.04770568021022842
# F1-Score: 0.043432766093761815
# Modified accuracy: 0.08409136850616536
# Latency increase from base: 11.64%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.0468971093592076
# F1-Score: 0.044581467861658446
# Modified accuracy: 0.08328279765514453
# Latency increase from base: 29.17%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.04851425106124924
# F1-Score: 0.04666895375951201
# Modified accuracy: 0.08510208206994138
# Latency increase from base: 58.20%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.048109965635738834
# F1-Score: 0.04667500549714213
# Modified accuracy: 0.08469779664443097
# Latency increase from base: 116.43%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.04790782292298363
# F1-Score: 0.04625817642734167
# Modified accuracy: 0.08409136850616536
# Latency increase from base: 290.27%
# Loading data...
# Loading model...
# Making predictions...
# /home/jay/Documents/Fall 2022/EECS 589/Project/eecs589-patel-schauer/venv/lib/python3.10/site-packages/sktime/datatypes/_panel/_convert.py:713: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for _label, _series in multi_ind_dataframe.iteritems():  # noqa
# Accuracy: 0.04184354154032747
# F1-Score: 0.037767606249030077
# Modified accuracy: 0.0780270871235092
# Latency increase from base: 581.22%
# ./minirocket_logreg_no_direction/model
# {0.001: (0.08166565595310289, 0.0058169659320072105),
#  0.002: (0.08105922781483728, 0.011603246730667972),
#  0.005: (0.0820699413786133, 0.029101477690262254),
#  0.01: (0.08348494036789973, 0.05812604018749166),
#  0.02: (0.08409136850616536, 0.11636996932266251),
#  0.05: (0.08328279765514453, 0.2916948758846483),
#  0.1: (0.08510208206994138, 0.582003609409159),
#  0.2: (0.08469779664443097, 1.164273943291468),
#  0.5: (0.08409136850616536, 2.9026709406979445),
#  1: (0.0780270871235092, 5.812151847199914)}

# %%
pprint(all_results)
# Out:
# {'./minirocket_logreg_no_direction/model': {0.001: (0.08166565595310289,
#                                                     0.0058169659320072105),
#                                             0.002: (0.08105922781483728,
#                                                     0.011603246730667972),
#                                             0.005: (0.0820699413786133,
#                                                     0.029101477690262254),
#                                             0.01: (0.08348494036789973,
#                                                    0.05812604018749166),
#                                             0.02: (0.08409136850616536,
#                                                    0.11636996932266251),
#                                             0.05: (0.08328279765514453,
#                                                    0.2916948758846483),
#                                             0.1: (0.08510208206994138,
#                                                   0.582003609409159),
#                                             0.2: (0.08469779664443097,
#                                                   1.164273943291468),
#                                             0.5: (0.08409136850616536,
#                                                   2.9026709406979445),
#                                             1: (0.0780270871235092,
#                                                 5.812151847199914)}}
